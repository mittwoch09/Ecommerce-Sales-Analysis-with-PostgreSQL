# %%
import pandas as pd
import psycopg2 as pg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://testuser:testpass@localhost:5432/postgresql_analysis')

con = pg2.connect(host='localhost',
                  user='testuser',
                  password='testpass',
                  database='postgresql_analysis')
con.autocommit = True
cur = con.cursor()

# %%
def select(query):
    return pd.read_sql(query, con)

# %%
query = """
        SELECT * FROM leads
        """

select(query)
# Out:
#                                 mql_id first_contact_date  \
# 0     dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1     8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2     b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3     6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4     5420aad7fec3549a85876ba1c529bd84         2018-02-21
# ...                                ...                ...
# 7995  feaba3ffcd2ff97501696c7f9a42f41c         2018-05-22
# 7996  a79cb53cd009ab92e0143b92baa2407b         2018-03-27
# 7997  68f049a23ab109c6a0f6989bb9a02994         2017-08-27
# 7998  4f8c96e2509b984329044c6682c88ee9         2017-10-06
# 7999  8a6492305a5fbcdcdd1a7f5a90764c07         2018-01-11
#
#                        landing_page_id          origin
# 0     88740e65d5d6b056e0cda098e1ea6313          social
# 1     007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2     a7982125ff7aa3b2054c6e44f9d28522  organic_search
# ...

# %%
query = """
        SELECT * FROM deals
        """

select(query)
# Out:
#                                mql_id                         seller_id  \
# 0    5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1    a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2    327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3    f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4    ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
# ..                                ...                               ...
# 837  df9a2abe2ad3f2d8758b675ac8331ecf  bfcc27719640628da877db48b672b169
# 838  8723201570415eb23b4f095d8c20a27c  4a82eab98441aeb64566e2776c1fb2b6
# 839  2e57665b8faf05c967a801eb5aedfa0a  55031883943971ca22db6894574cfe2c
# 840  40955be51cc85c5a5a6cdd12b19e9f10  c0e933c238e41f0cd459d6025ee9b364
# 841  8a6492305a5fbcdcdd1a7f5a90764c07  1bba9c94eb5c4e82fba9f7286fe81025
#
#                                sdr_id                             sr_id  \
# ...

# %% [markdown]
# ### Marketing channel and traffic source

# %% [markdown]
# n this dataset, we only have landing page as marketing channel. Let's see which landing page has the most signed up merchants.

# %%
query = """
        SELECT landing_page_id
            ,count(distinct mql_id) as num_leads
        FROM leads
        GROUP BY 1
        ORDER BY 2 desc
        LIMIT 10
        """

select(query)
# Out:
#                     landing_page_id  num_leads
# 0  b76ef37428e6799c421989521c0e5077        912
# 1  22c29808c4f815213303f8933030604c        883
# 2  58326e62183c14b0c03085c33b9fdc44        495
# 3  88740e65d5d6b056e0cda098e1ea6313        445
# 4  ce1a65abd0973638f1c887a6efcfa82d        394
# 5  40dec9f3d5259a3d2dbcdab2114fae47        330
# 6  f017be4dbf86243af5c1ebed0cff36a2        310
# 7  e492ee5eaf1697716985cc6f33f9cd9b        291
# 8  a7982125ff7aa3b2054c6e44f9d28522        156
# 9  73f31a40697cc90a86c1273563ac230e        115

# %% [markdown]
# Also, let's see how many leads each traffic source has.

# %%
query = """
        SELECT origin
            ,count(distinct mql_id) as num_leads
        FROM leads
        GROUP BY 1
        ORDER BY 2 desc
        """

select(query)
# Out:
#                origin  num_leads
# 0      organic_search       2296
# 1         paid_search       1586
# 2              social       1350
# 3             unknown       1099
# 4      direct_traffic        499
# 5               email        493
# 6            referral        284
# 7               other        150
# 8             display        118
# 9   other_publicities         65
# 10               None         60

# %% [markdown]
# We have missing value and 'unknown' category. But the problem is 'unknown' traffic source has a significant number of leads.

# %% [markdown]
# ### How long does it take to close a deal?

# %% [markdown]
# From the first contact date, based on the lead behaviour profile, I would like to know how long the lead decides to become Olist's seller.

# %% [markdown]
# lead behivour profile
#
# - Shark : Dominance
# - Eagle : Influence
# - Cat : Steadiness
# - Wolf : Conscientiousness

# %%
query = """
        SELECT lead_behaviour_profile
            ,round(avg(date_part('day', age(won_date, first_contact_date)))::decimal,2)
             as avg_days_diff
        FROM leads l
        JOIN deals d on l.mql_id = d.mql_id
        GROUP BY 1
        ORDER BY 2
        """

select(query)
# Out:
#   lead_behaviour_profile  avg_days_diff
# 0            shark, wolf           7.00
# 1                    cat           9.90
# 2                  eagle          10.26
# 3                  shark          10.67
# 4                   None          11.77
# 5                   wolf          12.14
# 6              cat, wolf          14.25
# 7             eagle, cat          16.33
# 8            eagle, wolf          16.67
# 9             shark, cat          28.00

# %% [markdown]
# It seems mixed profile leads are much harder to negotiate.

# %% [markdown]
# ### Merchants conversion rate

# %% [markdown]
# The conversion rate reflect the percentage of signed-up merchants that later become Olist sellers. First, let's see the number of leads and closed deals over time.

# %%
query = """
        SELECT a.year
            ,num_deals
            ,num_leads
            ,round(num_deals * 1.0 / num_leads * 100, 2) as conversion_rate
        FROM 
        (
            SELECT date_part('year', first_contact_date)::int as year
                 ,count(distinct mql_id) as num_leads
            FROM leads
            GROUP BY 1
        ) a
        JOIN 
        (
            SELECT date_part('year', won_date)::int as year
                 ,count(distinct mql_id) as num_deals
            FROM deals
            GROUP BY 1
        ) b on a.year = b.year
        """

select(query)
# Out:
#    year  num_deals  num_leads  conversion_rate
# 0  2017          3       2002             0.15
# 1  2018        839       5998            13.99

# %% [markdown]
# The conversion rate in 2017 is very low. In 2018, the conversion rate is still low. I would like to see how the conversion rate is different when it's come to different leads traffic source origin.

# %%
query = """
        SELECT origin
            ,sum(year_2017) as conversion_rate_2017
            ,sum(year_2018) as conversion_rate_2018            
        FROM
        (
            SELECT a.origin
                ,case when a.year = 2017 
                    then round(num_deals * 1.0 / num_leads * 100, 2) else 0 end as year_2017
                ,case when a.year = 2018
                    then round(num_deals * 1.0 / num_leads * 100, 2) else 0 end as year_2018
            FROM
            (
                SELECT origin
                    ,date_part('year', first_contact_date)::int as year
                    ,count(distinct mql_id) as num_leads
                FROM leads
                GROUP BY 1,2
            ) a
            JOIN
            (
                SELECT origin
                    ,date_part('year', won_date)::int as year
                    ,count(distinct d.mql_id) as num_deals
                FROM deals d
                JOIN leads l on d.mql_id = l.mql_id
                GROUP BY 1,2
            ) b on a.year = b.year and a.origin = b.origin
        ) c
        GROUP BY 1
        ORDER BY 3 desc
        
        """

select(query)
# Out:
#               origin  conversion_rate_2017  conversion_rate_2018
# 0            unknown                  0.00                 22.02
# 1        paid_search                  0.50                 16.33
# 2     organic_search                  0.00                 15.61
# 3     direct_traffic                  0.00                 14.74
# 4           referral                  0.00                 11.37
# 5  other_publicities                  0.00                  7.32
# 6             social                  0.00                  7.14
# 7            display                  2.33                  6.67
# 8              email                  0.00                  4.32
# 9              other                  0.00                  3.51

# %% [markdown]
# Besides the missing value, 'unknown' source has the highest rate. Olist should find out the missing information and focus on these kind of traffic source to see if it can help improve the conversion rate.

# %%
query = """
        SELECT month
            ,sr_id
            ,num_deals
        FROM 
        (
            SELECT date_part('month', won_date)::int as month
                ,sr_id
                ,count(distinct mql_id) as num_deals
                ,rank() over(partition by date_part('month', won_date)::int 
                    order by count(distinct mql_id) desc) as sales_rank
               FROM deals
               WHERE date_part('year', won_date) = 2018
               GROUP BY 1,2
        ) a
        WHERE sales_rank = 1
        """

select(query)
# Out:
#     month                             sr_id  num_deals
# 0       1  4ef15afb4b2723d8f3d81e51ec7afefe         18
# 1       2  4ef15afb4b2723d8f3d81e51ec7afefe         25
# 2       3  4ef15afb4b2723d8f3d81e51ec7afefe         22
# 3       4  4ef15afb4b2723d8f3d81e51ec7afefe         33
# 4       5  4ef15afb4b2723d8f3d81e51ec7afefe         18
# 5       6  4ef15afb4b2723d8f3d81e51ec7afefe         10
# 6       7  4b339f9567d060bcea4f5136b9f5949e          5
# 7       7  85fc447d336637ba1df43e793199fbc8          5
# 8       8  068066e24f0c643eb1d089c7dd20cd73          5
# 9       9  de63de0d10a6012430098db33c679b0b          5
# 10     10  068066e24f0c643eb1d089c7dd20cd73          5
# 11     11  34d40cdaf94010a1d05b0d6212f9e909          2

# %% [markdown]
# In 2018, sales rep '4ef15afb4b2723d8f3d81e51ec7afefe' seems very promising here. He brought in the most deals in the first 2 quarters. How about number of deals by business segment?

# %%
query = """
        SELECT month
            ,business_segment
            ,num_deals
        FROM 
        (
            SELECT date_part('month', won_date)::int as month
                ,business_segment
                ,count(distinct mql_id) as num_deals
                ,rank() over(partition by date_part('month', won_date)::int 
                    order by count(distinct mql_id) desc) as sales_rank
               FROM deals
               WHERE date_part('year', won_date) = 2018
               GROUP BY 1,2
        ) a
        WHERE sales_rank = 1
        """

select(query)
# Out:
#     month                 business_segment  num_deals
# 0       1                       home_decor         13
# 1       2                  car_accessories         12
# 2       2                       home_decor         12
# 3       3                       home_decor         18
# 4       4                       home_decor         29
# 5       5                    health_beauty         20
# 6       6          audio_video_electronics          7
# 7       7                       home_decor          6
# 8       8                       home_decor          6
# 9       9  construction_tools_house_garden          5
# 10     10              household_utilities          3
# 11     10  construction_tools_house_garden          3
# 12     10                       home_decor          3
# 13     11                            other          3

# %% [markdown]
# In 2018, we have 'home decoration' business mostly in top sales each month.
