# %%
import pandas as pd
import psycopg2 as pg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://testuser:testpass@localhost:5432/postgresql_analysis')

con = pg2.connect(host='localhost',
                  user='testuser',
                  password='testpass',
                  database='postgresql_analysis')
con.autocommit = True
cur = con.cursor()

# %%
def select(query):
    return pd.read_sql(query, con)

# %%
query = """
        SELECT * FROM orders
        """

select(query)
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
query = """
        SELECT * FROM customers
        """
select(query)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code          customer_city customer_state
# ...

# %%
query = """
        SELECT MIN(order_purchase_timestamp) AS first_order,
        MAX(order_purchase_timestamp) AS last_order
        FROM orders
        """

select(query)
# Out:
#           first_order          last_order
# 0 2016-09-04 21:15:19 2018-10-17 17:30:18

# %% [markdown]
# The first order was placed in the beginning of September 2019, and the last order was placed in the middle of October 2018.

# %%
query = """
        SELECT date_part('year', order_purchase_timestamp)::int AS year
            ,date_part('month', order_purchase_timestamp)::int AS month
        FROM orders
        GROUP BY year, month
        ORDER BY year, month
        """

select(query)
# Out:
#     year  month
# 0   2016      9
# 1   2016     10
# 2   2016     12
# 3   2017      1
# 4   2017      2
# 5   2017      3
# 6   2017      4
# 7   2017      5
# 8   2017      6
# 9   2017      7
# 10  2017      8
# 11  2017      9
# 12  2017     10
# 13  2017     11
# 14  2017     12
# 15  2018      1
# 16  2018      2
# 17  2018      3
# 18  2018      4
# 19  2018      5
# 20  2018      6
# 21  2018      7
# 22  2018      8
# 23  2018      9
# 24  2018     10

# %% [markdown]
# We have a missing month which is November, in 2016.

# %% [markdown]
# ### Number of customers and customers growth rate

# %% [markdown]
# I would like to know the number of new customers increasing each year.

# %%
query = """
        SELECT date_part('year', order_purchase_timestamp)::int AS year
            ,count(distinct customer_unique_id) AS num_customers
        FROM customers c 
        JOIN orders o on c.customer_id = o.customer_id
        GROUP BY 1
        """

select(query)
# Out:
#    year  num_customers
# 0  2016            326
# 1  2017          43713
# 2  2018          52749

# %%
query = """
        WITH num_customers_year as
        (
            SELECT date_part('year', order_purchase_timestamp)::int AS year
                ,count(distinct customer_unique_id) AS num_customers
            FROM customers c
            JOIN orders o on c.customer_id = o.customer_id
            GROUP BY 1
        )
        SELECT year
            ,first_value(num_customers) over (order by year) AS cohort_size
            ,num_customers
            ,round(num_customers / first_value(num_customers) over (order by year) * 100, 2) AS customers_growth
        FROM num_customers_year
        """

select(query)
# Out:
#    year  cohort_size  num_customers  customers_growth
# 0  2016          326            326             100.0
# 1  2017          326          43713           13400.0
# 2  2018          326          52749           16100.0

# %% [markdown]
# ### Customers repeating rate

# %%
query = """
        SELECT a.year, c.repeat_customers, a.num_customers,
               round(c.repeat_customers * 1.0 / a.num_customers * 100, 2) AS repeat_rate
        FROM (SELECT date_part('year', order_purchase_timestamp)::int AS year,
                     COUNT(DISTINCT customer_unique_id) AS num_customers             
              FROM customers c JOIN orders o
              ON c.customer_id = o.customer_id
              GROUP BY year) a
        JOIN (SELECT year, COUNT(DISTINCT customer_unique_id) AS repeat_customers
        FROM (SELECT CASE ROW_NUMBER() 
                OVER(PARTITION BY customer_unique_id 
                     ORDER BY order_purchase_timestamp)
           WHEN 1 THEN 'Total'
           ELSE 'Return'
           END AS customer_type, c.customer_unique_id,
           date_part('year', order_purchase_timestamp)::int AS year
        FROM customers c JOIN orders o
        ON c.customer_id = o.customer_id
        ORDER BY customer_unique_id, order_purchase_timestamp) b
        WHERE customer_type = 'Return'
        GROUP BY year, customer_type) c ON a.year = c.year;
        """

select(query)
# Out:
#    year  repeat_customers  num_customers  repeat_rate
# 0  2016                 3            326         0.92
# 1  2017              1261          43713         2.88
# 2  2018              1799          52749         3.41

# %% [markdown]
# There is a serious problem with customer's repeat purchase rates.
